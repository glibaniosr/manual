# %% [markdown]
# # MC-PDFT
#
# MC-PDFT is a method that combines CASSCF and DFT, by making use of the on-top pair density $\pi$, instead of the spin-densities, usual for regular Kohn-Sham DFT.

# %% [markdown]
# ## Single-state MC-PDFT

# %%
import veloxchem as vlx
import multipsi as mtp
furan_xyz="""9

 C     -0.86213    -0.90784     0.00007
 H     -1.63433    -1.64264    -0.00003
 C      0.50727    -0.90524     0.00007
 C      0.92057     0.47886    -0.00003
 C     -0.22323     1.23186    -0.00003
 O     -1.35123     0.40376    -0.00013
 H      1.17117    -1.74724     0.00017
 H      1.93767     0.81866     0.00007
 H     -0.46573     2.26986    -0.00013
"""

molecule = vlx.Molecule.from_xyz_string(furan_xyz)
basis = vlx.MolecularBasis.read(molecule,"def2-sv(p)")
states = 1

# Using a guess from a MCSCF calculation
space = mtp.OrbSpace(molecule, "furan-cas.svp.h5")
mcdrv = mtp.McscfDriver()
mcdrv.xcfun = "tpbe"
results_dict = mcdrv.compute(molecule, basis, space, states)

# %% [markdown]
# ## State-average MC-PDFT
#
# Suppose you want to calculate the first two excited states of furan. One way of doing this is using a state-average complete active space calculation (SA-CAS), that can make use of PDFT (SA-MC-PDFT) or not (SA-CASSCF). In SA-CAS, several states are optimized at the same time, albeit using the same set of molecular orbitals. Therefore, each state contributes to the final energy and the final orbitals will be a mix of all states.

# %%
results_dict = mcdrv.compute(molecule, basis, space, 3)
# Out:
#
#                           Multi-Configurational Self-Consistent Field Driver
#                          ====================================================
#
#
#                Active space definition:
#                ------------------------
#                Number of inactive (occupied) orbitals: 15
#                Number of active orbitals:              5
#                Number of virtual orbitals:             58
#
#                This is a CASSCF wavefunction: CAS(6,5)
#
#                CI expansion:
#                -------------
#                Number of determinants:      100
#
#
#
#                ╭────────────────────────────────────╮
#                │          Driver settings           │
#                ╰────────────────────────────────────╯
#
#                Functional                    :   tPBE
#                Grid level                    :   4
#
#                Number of states              :   3
#                State-averaged calculation
#                 - Equal-weights
#                Max. iterations               :   50
#                BFGS window                   :   5
#                Convergence thresholds:
#                 - Energy change              :   1e-08
#                 - Gradient sq. norm          :   1e-08
#
#
#                           MC-PDFT Iterations
#                          -------------------
#
#      Iter. | Average Energy | E. Change | Grad. Norm | CI Iter. | Trust rad. |  Time
#      ---------------------------------------------------------------------------------
#         1     -229.408996905     0.0e+00      9.3e-03         19        0.40    0:01:07
#         2     -229.435293501    -2.6e-02      5.1e-03         32        0.40    0:02:06
#         3     -229.436191063    -9.0e-04      2.7e-03          4        0.48    0:00:33
#         4     -229.436998448    -8.1e-04      6.5e-05          4        0.34    0:00:25
#         5     -229.437015670    -1.7e-05      2.2e-05          3        0.34    0:00:22
#         6     -229.437021373    -5.7e-06      9.0e-07          5        0.34    0:00:59
#         7     -229.437021559    -1.9e-07      2.9e-07          5        0.34    0:01:49
#         8     -229.437021650    -9.0e-08      3.3e-09          5        0.34    0:00:30
#         9     -229.437021652    -1.8e-09      8.8e-10          4        0.34    0:00:27
# ** Convergence reached in 9 iterations
#        10     -229.436574375     4.5e-04      5.5e-05         40        0.34    0:01:36
#
#                Final results
#                -------------
#
# * State 1
#   - S^2    : 0.00  (multiplicity = 1.0 )
#   - Energy : -229.57167202513247
#   - Natural orbitals
# 1.99844 1.99394 1.98936 0.01083 0.00744
#
# * State 2
#   - S^2    : 0.00  (multiplicity = 1.0 )
#   - Energy : -229.37177306228622
#   - Natural orbitals
# 1.99879 1.98687 1.00832 0.99235 0.01367
#
# * State 3
#   - S^2    : 1.98  (multiplicity = 3.0 )
#   - Energy : -229.36627803707506
#   - Natural orbitals
# 1.99686 1.34239 1.64622 0.66073 0.35381
#
#                                                  Spin Restricted Orbitals
#                                                  ------------------------
#
#                Molecular Orbital No.  14:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.35351 a.u.
#                (   1 C   1p+1:     0.16) (   3 C   1p-1:    -0.37) (   4 C   1p-1:     0.38)
#                (   7 H   1s  :     0.17) (   8 H   1s  :     0.17)
#
#                Molecular Orbital No.  15:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.32179 a.u.
#                (   1 C   1p+1:     0.19) (   3 C   1p+1:    -0.19) (   4 C   1p+1:    -0.16)
#                (   5 C   1p+1:     0.22) (   6 O   2s  :     0.17) (   6 O   3s  :     0.18)
#                (   6 O   1p+1:    -0.50) (   6 O   2p+1:    -0.33)
#
#                Molecular Orbital No.  16:
#                --------------------------
#                Occupation: 1.995 Energy:   -0.38538 a.u.
#                (   1 C   1p0 :    -0.23) (   5 C   1p0 :    -0.23) (   6 O   1p0 :    -0.47)
#                (   6 O   2p0 :    -0.30)
#
#                Molecular Orbital No.  17:
#                --------------------------
#                Occupation: 1.800 Energy:   -0.24909 a.u.
#                (   3 C   1p0 :    -0.35) (   3 C   2p0 :    -0.23) (   4 C   1p0 :    -0.35)
#                (   4 C   2p0 :    -0.23) (   6 O   1p0 :     0.36) (   6 O   2p0 :     0.27)
#
#                Molecular Orbital No.  18:
#                --------------------------
#                Occupation: 1.521 Energy:   -0.20799 a.u.
#                (   1 C   1p0 :    -0.38) (   1 C   2p0 :    -0.27) (   3 C   1p0 :    -0.24)
#                (   3 C   2p0 :    -0.18) (   4 C   1p0 :     0.24) (   4 C   2p0 :     0.18)
#                (   5 C   1p0 :     0.38) (   5 C   2p0 :     0.27)
#
#                Molecular Orbital No.  19:
#                --------------------------
#                Occupation: 0.532 Energy:   -0.02776 a.u.
#                (   1 C   1p0 :    -0.38) (   1 C   2p0 :    -0.44) (   3 C   1p0 :     0.22)
#                (   3 C   2p0 :     0.27) (   4 C   1p0 :     0.22) (   4 C   2p0 :     0.27)
#                (   5 C   1p0 :    -0.38) (   5 C   2p0 :    -0.44) (   6 O   1p0 :     0.35)
#                (   6 O   2p0 :     0.35)
#
#                Molecular Orbital No.  20:
#                --------------------------
#                Occupation: 0.152 Energy:    0.02716 a.u.
#                (   1 C   1p0 :    -0.29) (   1 C   2p0 :    -0.40) (   3 C   1p0 :     0.43)
#                (   3 C   2p0 :     0.62) (   4 C   1p0 :    -0.43) (   4 C   2p0 :    -0.62)
#                (   5 C   1p0 :     0.29) (   5 C   2p0 :     0.40)
#
#                Molecular Orbital No.  21:
#                --------------------------
#                Occupation: 0.000 Energy:    0.05995 a.u.
#                (   1 C   3s  :     0.49) (   1 C   1p-1:    -0.15) (   1 C   2p-1:    -0.29)
#                (   2 H   2s  :    -0.74) (   3 C   3s  :     0.76) (   3 C   2p+1:     0.31)
#                (   3 C   2p-1:    -0.33) (   4 C   3s  :     0.76) (   4 C   1p+1:     0.19)
#                (   4 C   2p+1:     0.44) (   5 C   3s  :     0.49) (   5 C   1p-1:     0.16)
#                (   5 C   2p-1:     0.31) (   6 O   3s  :     0.22) (   6 O   2p+1:     0.15)
#                (   7 H   2s  :    -1.19) (   8 H   2s  :    -1.19) (   9 H   2s  :    -0.74)
#
#                Molecular Orbital No.  22:
#                --------------------------
#                Occupation: 0.000 Energy:    0.08913 a.u.
#                (   1 C   2s  :     0.24) (   1 C   3s  :     1.07) (   1 C   1p+1:    -0.15)
#                (   1 C   2p+1:    -0.61) (   1 C   2p-1:    -0.16) (   2 H   2s  :    -1.37)
#                (   3 C   3s  :    -0.27) (   3 C   2p+1:    -0.16) (   3 C   2p-1:     0.29)
#                (   4 C   3s  :    -0.27) (   4 C   2p+1:    -0.29) (   4 C   2p-1:    -0.16)
#                (   5 C   2s  :     0.24) (   5 C   3s  :     1.07) (   5 C   2p+1:    -0.42)
#                (   5 C   2p-1:     0.47) (   6 O   2s  :    -0.17) (   6 O   3s  :    -0.56)
#                (   6 O   1p+1:    -0.17) (   7 H   2s  :     0.61) (   8 H   2s  :     0.61)
#                (   9 H   2s  :    -1.38)
#
#
#                                                 Dipole moment for state 1
#                                                ---------------------------
#
#                                    X   :         0.249650 a.u.         0.634547 Debye
#                                    Y   :        -0.074758 a.u.        -0.190017 Debye
#                                    Z   :         0.000051 a.u.         0.000130 Debye
#                                  Total :         0.260603 a.u.         0.662387 Debye
#
#
#                                                 Dipole moment for state 2
#                                                ---------------------------
#
#                                    X   :         0.333474 a.u.         0.847607 Debye
#                                    Y   :        -0.099024 a.u.        -0.251694 Debye
#                                    Z   :        -0.000036 a.u.        -0.000091 Debye
#                                  Total :         0.347866 a.u.         0.884187 Debye
#
#
#                                                 Dipole moment for state 3
#                                                ---------------------------
#
#                                    X   :         0.319676 a.u.         0.812536 Debye
#                                    Y   :        -0.094161 a.u.        -0.239333 Debye
#                                    Z   :        -0.000038 a.u.        -0.000096 Debye
#                                  Total :         0.333255 a.u.         0.847050 Debye
#
#
# Total MC-PDFT time: 00:09:59

# %% [markdown]
# We can also compute the transition energy and intensities by making use of the StateInteraction class, which uses as argument the dictionary obtained at the end of a SA-CAS run.

# %%
SI = mtp.StateInteraction()
osc_dic = SI.compute(molecule, basis, results_dict)
# Out:
#
# List of oscillator strengths greather than 1e-10
#
#   From     to       Energy (eV)    Oscillator strength (length and velocity)
#      1       2        5.43953         3.778467e-01    3.209755e-01
#      1       3        5.58906         2.346873e-04    2.086066e-04
#
# List of rotatory strengths greather than 1e-10
#
#   From     to       Energy (eV)    Rot. strength (a.u. and 10^-40 cgs)
#      1       2        5.43953        -2.221173e-05   -1.047158e-02
#      1       3        5.58906        -1.950505e-08   -9.195532e-06

# %%
orbviewer=mtp.OrbitalViewer()
orbviewer.plot(molecule, basis, space)
# Out:
# Output()
# Dropdown(description='Orbital:', index=17, options=(('  1 occ=2.000 ene=-18.809  (alpha HOMO-17)', 0), ('  2 o…
# Checkbox(value=True, description='Active')
# Output()
# HBox(children=(Text(value='input-cas.h5', description='Filename'), Button(description='Save h5 file', style=Bu…
